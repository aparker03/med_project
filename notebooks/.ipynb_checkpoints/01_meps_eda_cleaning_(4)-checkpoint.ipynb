# %% [markdown]
# # MEPS Part II: Total Health Care Expenditures (Regression)
#
# Part II is a regression task. The target is `TOTEXP23`, total health care expenditures in 2023 from the MEPS HC-251 Full Year Consolidated file. The goal is to model how much an individual spends on health care in a year given their demographics, health status, functioning, insurance, and access characteristics.
#
# Part I (NHIS) framed cost-related access barriers as a binary classification problem (delayed or unmet care because of cost). Part II reuses some of the same access-barrier indicators, but as **predictors** rather than the target — they describe whether someone faced affordability friction during the year, which is a plausible driver of the spending pattern, not the outcome being predicted.
#
# The data decisions that drive this notebook are listed in the next section. The codebook (`h251cb.pdf`) is the authoritative reference for variable definitions, value labels, and reserved codes.
#
# **Output files produced:**
# - `data/interim/meps_adult_target_cleaned.csv` — adult-only file with target and `log1p` target.
# - `data/interim/meps_first_pass_cleaned_candidates.csv` — adult-only file after reserved-code cleaning.
# - `data/processed/meps_model_ready_v1.csv` — primary model-ready file.
# - `data/processed/meps_model_ready_v1_with_saq.csv` — sensitivity model-ready file that adds the SAQ mental-health variables back in.

# %% [markdown]
# ## Data decisions
#
# These choices set the scope and feature set for the MEPS Part II cleaning pass and are implemented in the cells below.
#
# - **Filter to adults only: `AGE23X >= 18`.** Aligns the MEPS sample with the NHIS Part I Sample Adult population. The filter is applied right after loading so all subsequent EDA — spending summaries, skewness, and plots — uses the adult population that is actually modeled. Implemented in *Filter to adults*.
# - **Keep `TOTEXP23` as the regression target.** A `log1p(TOTEXP23)` sensitivity version is computed alongside the raw target so we can compare linear models on each scale. Implemented in *Target variable: TOTEXP23* and used throughout.
# - **Use `POVCAT23` as the main poverty variable.** Treated as a categorical predictor; residual missing values are filled with `"Unknown"` to preserve skip-pattern signal. Implemented in *Candidate variables for the first cleaning pass* and *Handle selected categorical missing values*.
# - **Keep `POVLEV23` only as a sensitivity option.** Kept in the interim cleaned file (`meps_first_pass_cleaned_candidates.csv`) but dropped from the model-ready file via the `drop_secondary_poverty` list to avoid collinearity with `POVCAT23`. Implemented in *Drop variables not used in the first model-ready file*.
# - **Drop all other dollar expenditure variables so we do not leak the target.** A prefix/suffix rule scans the full 1,374-column MEPS file space and drops every 2023 expenditure or payment-source column (`{TOT,OB,OP,ER,IP,HH,DV,VIS,RX,OTH} × {EXP,SLF,MCR,MCD,PRV,VA,TRI,OFD,STL,WCP,OSR,PTR,OTH,TCH} × 23`) except `TOTEXP23` itself. Mechanically related utilization counts (`OBTOTV23`, `RXTOT23`, `IPDIS23`, `ERTOT23`, etc.) are dropped too. Implemented in *Drop variables not used in the first model-ready file*.
# - **Fix functioning features by separating yes/no limitation variables from ordinal difficulty variables.** Two separate features are produced: `limitation_indicator_count` from the `*LIM31` general-limitation screeners (`WLKLIM31`, `ACTLIM31`, `SOCLIM31`, `COGLIM31`), and `physical_difficulty_count` from the `DF*42` Census six-item serious-difficulty set (`DFHEAR42`, `DFSEE42`, `DFCOG42`, `DFWLKC42`, `DFDRSB42`, `DFERND42`). *Codebook note for HC-251 specifically:* the `DF*42` items in this file are coded as binary 1=YES / 2=NO (the codebook entries show only 1 and 2 as valid responses, with negative reserved codes for missingness) — they are not on a 4-level ordinal scale in this file as they are in some other surveys. The conceptual two-feature split is preserved as requested so a later analysis can attribute predictive weight to general limitations vs. specific physical-difficulty domains separately, and both features use the same `count_yes_values` helper because both groups are binary in HC-251. Implemented in *Candidate variables for the first cleaning pass* and *Create broader feature groups*.
# - **Drop `WRKLIM31` from the first model-ready file.** Work-limitation status is structurally missing for most adults in HC-251 (it is asked of a narrow employment subframe), so it adds little signal at high cost in row count. The four other limitation screeners (`WLKLIM31`, `ACTLIM31`, `SOCLIM31`, `COGLIM31`) are kept. Implemented in *Candidate variables for the first cleaning pass* and *Reserved code cleaning rules*.
# - **SAQ mental-health variables go to a sensitivity-only file.** The Self-Administered Questionnaire variables `K6SUM42`, `PHQ242`, `ADINTR42`, `ADDPRS42` carry meaningful skip-pattern missingness (the SAQ is collected on a subframe of adults). They are kept in the interim cleaned file and in a second model-ready file (`meps_model_ready_v1_with_saq.csv`) for sensitivity analysis, but dropped from the primary model-ready file to keep the headline model on the broader adult population. The non-SAQ perceived mental-health item (`MNHLTH42`) is asked in the regular interview and stays in the primary file. Implemented in *Drop variables not used in the first model-ready file*.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## File paths
#
# The project is organized so the same relative paths work in PyCharm and Colab. The local workflow uses the `med_project` folder directly. The Colab mount code is included but commented out because local work is the main workflow right now.

# %%
# Colab option
from google.colab import drive
drive.mount("/content/drive")
PROJECT_ROOT = Path("/content/drive/MyDrive/med_project")

# Local/PyCharm option (Commented out for Colab)
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()

DATA_RAW = PROJECT_ROOT / "data" / "raw"
DATA_INTERIM = PROJECT_ROOT / "data" / "interim"
DATA_PROCESSED = PROJECT_ROOT / "data" / "processed"
REPORTS = PROJECT_ROOT / "reports"

DATA_INTERIM.mkdir(parents=True, exist_ok=True)
DATA_PROCESSED.mkdir(parents=True, exist_ok=True)
REPORTS.mkdir(parents=True, exist_ok=True)

print("Project root:", PROJECT_ROOT)
print("Raw data folder:", DATA_RAW)
print("Reports folder:", REPORTS)
# Out:
# Mounted at /content/drive
# Project root: /content/drive/MyDrive/med_project
# Raw data folder: /content/drive/MyDrive/med_project/data/raw
# Reports folder: /content/drive/MyDrive/med_project/reports

# %% [markdown]
# ## Load the MEPS Full Year Consolidated file
#
# The HC-251 file is the base file for Part II because it contains the demographic, health, functioning, insurance, access, and expenditure variables needed for the regression task. Excel is read with `pd.read_excel`; for very large files, converting to CSV or Parquet first is faster, but the consolidated PUF reads cleanly as an `.xlsx`. The codebook (`h251cb.pdf`) is the authoritative reference for column meanings and reserved codes.

# %%
meps_path = DATA_RAW / "meps_2023_hc251_full_year_consolidated.xlsx"

meps_full = pd.read_excel(meps_path)

print("Full MEPS file shape:", meps_full.shape)
meps_full.head()
# Out:
# Full MEPS file shape: (18919, 1374)
#       DUID  PID    DUPERSID  PANEL  DATAYEAR FAMID31 FAMID42 FAMID53 FAMID23  \
# 0  2790002  101  2790002101     27      2023       A       A       A       A
# 1  2790002  102  2790002102     27      2023       A       A       A       A
# 2  2790004  101  2790004101     27      2023       A       A       A       A
# 3  2790006  101  2790006101     27      2023       A       A       A       A
# 4  2790006  102  2790006102     27      2023       A       A       A       A
#
#   FAMIDYR  ... RXWCP23  RXOSR23  RXPTR23 RXOTH23      PERWT23F      FAMWT23F  \
# 0       A  ...       0        0       82       0  11664.426815  11158.817826
# 1       A  ...       0        0        0       0  32212.113596  11158.817826
# 2       A  ...       0        0        0       0  21944.142826  28540.745942
# 3       A  ...       0        0        0       0  10328.009530  10821.040689
# 4       A  ...       0        0        0       0  17430.521357  10821.040689
#
#        FAMWT23C      SAQWT23F  VARSTR  VARPSU
# 0  11158.817826  13221.315673    2019       1
# 1  11158.817826      0.000000    2019       1
# 2  28540.745942  29999.277476    2084       1
# 3  10821.040689  11144.513916    2113       1
# 4  10821.040689      0.000000    2113       1
#
# [5 rows x 1374 columns]

# %% [markdown]
# ## Check column names against the codebook
#
# Before cleaning, the file structure needs to be checked against the codebook. The first pass only confirms that the regression target and key design columns are present. The codebook lists each variable name, its byte position, and its allowable values; a quick cross-check now prevents silent column-name typos later.

# %%
print("Total columns:", meps_full.shape[1])
meps_full.columns[:30].tolist()
# Out:
# Total columns: 1374
# ['DUID',
#  'PID',
#  'DUPERSID',
#  'PANEL',
#  'DATAYEAR',
#  'FAMID31',
#  'FAMID42',
#  'FAMID53',
#  'FAMID23',
#  'FAMIDYR',
#  'CPSFAMID',
#  'FCSZ1231',
#  'FCRP1231',
#  'RULETR31',
#  'RULETR42',
#  'RULETR53',
#  'RULETR23',
#  'RUSIZE31',
#  'RUSIZE42',
#  'RUSIZE53',
#  'RUSIZE23',
#  'RUCLAS31',
#  'RUCLAS42',
#  'RUCLAS53',
#  'RUCLAS23',
#  'FAMSZE31',
#  'FAMSZE42',
#  'FAMSZE53',
#  'FAMSZE23',
#  'FMRS1231']

# %%
expected_columns = [
    "DUPERSID",
    "PANEL",
    "PERWT23F",
    "VARSTR",
    "VARPSU",
    "REGION23",
    "AGE23X",
    "SEX",
    "TOTEXP23",
    "DLAYCA42",
    "AFRDCA42",
    "DLAYPM42",
    "AFRDPM42",
]

missing_expected = [col for col in expected_columns if col not in meps_full.columns]

if missing_expected:
    print("Missing expected columns:", missing_expected)
else:
    print("All expected columns are present.")
# Out:
# All expected columns are present.

# %% [markdown]
# ## Filter to adults
#
# The MEPS file includes children, but our NHIS Part I work is built on the Sample Adult file. To keep both parts on a comparable population — and to avoid pulling in child-only variables by accident — we restrict MEPS to `AGE23X >= 18` here, before any of the target review or EDA. Every plot, summary, and saved file from this point on is computed on the adult population that is actually modeled.

# %%
adult_mask = meps_full["AGE23X"] >= 18
meps = meps_full.loc[adult_mask].reset_index(drop=True)

print("Rows in full file:   ", meps_full.shape[0])
print("Rows after adult filter:", meps.shape[0])
print("Adult share:        ", f"{meps.shape[0] / meps_full.shape[0]:.1%}")
print("Min adult age:      ", int(meps["AGE23X"].min()))
print("Max adult age:      ", int(meps["AGE23X"].max()))
# Out:
# Rows in full file:    18919
# Rows after adult filter: 15123
# Adult share:         79.9%
# Min adult age:       18
# Max adult age:       85

# %% [markdown]
# ## Target variable: TOTEXP23 (adults only)
#
# `TOTEXP23` is the total health care expenditure for the person in calendar year 2023, summed across all event types (office-based visits, outpatient, emergency room, inpatient, home health, dental, vision, prescription drugs, and other). Per the codebook the value is a non-negative dollar amount: `0` is a true value (no care used), and the upper tail extends into the hundreds of thousands of dollars.
#
# Because `TOTEXP23` is a constructed dollar field with no skip patterns, it does not carry the negative reserved codes (`-1`, `-7`, `-8`, `-9`, `-15`) that appear on survey questions. We still defensively check for them below before treating the column as clean. All summary statistics here are on the adult-only frame so they describe the population we will actually model.

# %%
target_var = "TOTEXP23"

print(f"\n{target_var} summary statistics (adults only)")
print(meps[target_var].describe())

print(f"\nReserved-code check (should be empty for {target_var}):")
reserved_codes_meps = [-1, -7, -8, -9, -15]
print(meps[meps[target_var].isin(reserved_codes_meps)][target_var].value_counts())

print(f"\nNaN count: {meps[target_var].isna().sum()}")
print(f"Negative values count: {(meps[target_var] < 0).sum()}")
# Out:
# TOTEXP23 summary statistics (adults only)
# count     15123.000000
# mean       9634.878728
# std       23302.553321
# min           0.000000
# 25%         399.000000
# 50%        2458.000000
# 75%        8714.500000
# max      574675.000000
# Name: TOTEXP23, dtype: float64
#
# Reserved-code check (should be empty for TOTEXP23):
# Series([], Name: count, dtype: int64)
#
# NaN count: 0
# Negative values count: 0

# %% [markdown]
# ## Zeros, skewness, and a log1p sensitivity version (adults only)
#
# MEPS expenditure data is the textbook example of a semi-continuous distribution. A large share of people have `TOTEXP23 = 0` (no medical care used in the year), and the remaining values are heavily right-skewed by a small number of very-high-cost cases.
#
# We summarize three things here, all on the adult population:
#
# 1. The share of zeros, which tells us how much of the outcome is concentrated at the floor.
# 2. The skewness and a percentile snapshot, which tells us how much the right tail will dominate a linear-loss model.
# 3. A `log1p(TOTEXP23)` sensitivity version, which compresses the tail and is what we will compare a linear-on-raw-scale model against in the modeling notebook. `log1p` is used (not `log`) because it is defined at zero.

# %%
n = len(meps)
n_zero = int((meps[target_var] == 0).sum())
n_pos = int((meps[target_var] > 0).sum())

print(f"Total adult persons:     {n}")
print(f"Zero spenders:           {n_zero}  ({n_zero / n:.1%})")
print(f"Positive spenders:       {n_pos}  ({n_pos / n:.1%})")

print("\nPercentiles of TOTEXP23 (adults, all):")
print(meps[target_var].quantile([0.5, 0.75, 0.9, 0.95, 0.99, 0.999]).round(2))

print("\nPercentiles of TOTEXP23 (adults, positive spenders only):")
pos_only = meps.loc[meps[target_var] > 0, target_var]
print(pos_only.quantile([0.5, 0.75, 0.9, 0.95, 0.99, 0.999]).round(2))

print(f"\nRaw skewness (adults):           {meps[target_var].skew():.2f}")
print(f"Raw kurtosis (adults, excess):   {meps[target_var].kurt():.2f}")
# Out:
# Total adult persons:     15123
# Zero spenders:           2053  (13.6%)
# Positive spenders:       13070  (86.4%)
#
# Percentiles of TOTEXP23 (adults, all):
# 0.500      2458.00
# 0.750      8714.50
# 0.900     24243.20
# 0.950     42134.20
# 0.990    105948.02
# 0.999    268018.73
# Name: TOTEXP23, dtype: float64
#
# Percentiles of TOTEXP23 (adults, positive spenders only):
# 0.500      3420.00
# 0.750     10515.50
# 0.900     27797.80
# 0.950     46914.95
# 0.990    114417.39
# 0.999    273050.91
# Name: TOTEXP23, dtype: float64
#
# Raw skewness (adults):           7.62
# Raw kurtosis (adults, excess):   99.11

# %%
# Create the log1p sensitivity target. Defined for zero, monotone in the raw target.
meps["TOTEXP23_log1p"] = np.log1p(meps[target_var])

print("log1p(TOTEXP23) summary (adults):")
print(meps["TOTEXP23_log1p"].describe())
print(f"\nlog1p skewness:  {meps['TOTEXP23_log1p'].skew():.2f}")
print(f"log1p kurtosis: {meps['TOTEXP23_log1p'].kurt():.2f}")
# Out:
# log1p(TOTEXP23) summary (adults):
# count    15123.000000
# mean         6.941272
# std          3.202384
# min          0.000000
# 25%          5.991465
# 50%          7.807510
# 75%          9.072858
# max         13.261562
# Name: TOTEXP23_log1p, dtype: float64
#
# log1p skewness:  -1.13
# log1p kurtosis: 0.37

# %%
# Visualize the raw target vs the log1p target on the adult-only frame.
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].hist(meps[target_var], bins=60, color="#4C72B0", edgecolor="white")
axes[0].set_title("TOTEXP23 (raw dollars), adults")
axes[0].set_xlabel("$")
axes[0].set_ylabel("count")

# Same plot, capped at the 99th percentile so the long tail does not flatten the bars.
cap = meps[target_var].quantile(0.99)
axes[1].hist(meps.loc[meps[target_var] <= cap, target_var], bins=60, color="#DD8452", edgecolor="white")
axes[1].set_title(f"TOTEXP23 (adults, capped at 99th pct = ${cap:,.0f})")
axes[1].set_xlabel("$")

axes[2].hist(meps["TOTEXP23_log1p"], bins=60, color="#55A868", edgecolor="white")
axes[2].set_title("log1p(TOTEXP23), adults")
axes[2].set_xlabel("log1p($)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save the first target-cleaned file
#
# The interim file contains the adult-only rows with the raw target and the `log1p` sensitivity target. `TOTEXP23` is observed for every person, so no rows are dropped on a target check. This file is a stable starting point for the next cleaning step.

# %%
clean_target_meps = meps.copy()

output_path = DATA_INTERIM / "meps_adult_target_cleaned.csv"
clean_target_meps.to_csv(output_path, index=False)

print("Saved:", output_path)
print("Saved shape:", clean_target_meps.shape)
# Out:
# Saved: /content/drive/MyDrive/med_project/data/interim/meps_adult_target_cleaned.csv
# Saved shape: (15123, 1375)

# %% [markdown]
# ## Candidate variables for the first cleaning pass
#
# The first cleaning pass starts with variables that are plausible drivers of total health spending: demographics, income/poverty, health need (chronic conditions, perceived health, mental health screens), functioning/disability, insurance, access (usual source of care), and the cost-related access barriers from Part I — kept here as **predictors**, not the target.
#
# The raw MEPS file contains reserved response codes. These codes need to be handled carefully because they do not all mean the same thing. Per the codebook, MEPS uses negative reserved values: `-1` (inapplicable), `-7` (refused), `-8` (don't know), `-9` (not ascertained), and `-15` (cannot be computed). These should not be treated as ordinary numeric values.
#
# The functioning/disability candidates are split into two conceptual groups so they can be summarized as separate features later: **limitation indicators** (`*LIM31`) ask whether the person has any limitation in a domain, and **serious-difficulty indicators** (`DF*42`) ask whether the person has serious difficulty performing a specific physical or sensory function (the Census six-item disability set). In HC-251 both groups are coded as binary 1=YES / 2=NO per the codebook.
#
# **`WRKLIM31` is excluded** because it is structurally missing for most adults in HC-251 (asked only of a narrow employment subframe). The other four limitation screeners are kept.
#
# **The SAQ mental-health variables** (`K6SUM42`, `PHQ242`, `ADINTR42`, `ADDPRS42`) are listed in `saq_mental_health_vars` and flow through reserved-code cleaning, but they are dropped from the primary model-ready file later and saved into a separate sensitivity model-ready file.

# %%
# Core variables for the first MEPS cleaning pass.
# These are grouped by role so the keep/drop logic stays readable.

id_design_vars = [
    "DUPERSID",
    "PANEL",
    "DATAYEAR",
    "PERWT23F",
    "VARSTR",
    "VARPSU",
]

target_vars = ["TOTEXP23", "TOTEXP23_log1p"]

demographic_vars = [
    "AGE23X",
    "SEX",
    "RACETHX",
    "HISPANX",
    "MARRY23X",
    "REGION23",
    "EDUCYR",
    "HIDEG",
    "BORNUSA",
    "FAMSZEYR",
]

# POVCAT23 is the primary poverty feature (categorical, easy to explain).
# POVLEV23 is kept here for the interim file as a sensitivity option but will be
# dropped from the final model-ready file to avoid collinearity with POVCAT23.
income_vars = [
    "POVCAT23",
    "POVLEV23",
    "FOODST23",
]

# Non-SAQ health-need variables. These stay in the primary model-ready file.
health_need_vars = [
    "RTHLTH42",
    "MNHLTH42",
    "HIBPDX",
    "CHOLDX",
    "DIABDX_M18",
    "ASTHDX",
    "ARTHDX",
    "CANCERDX",
    "CHDDX",
    "STRKDX",
    "EMPHDX",
]

# SAQ mental-health variables. Kept in interim files, used only in the sensitivity
# model-ready file because of skip-pattern missingness.
saq_mental_health_vars = [
    "K6SUM42",
    "PHQ242",
    "ADINTR42",
    "ADDPRS42",
]

# Two functioning/disability sub-groups, both binary in HC-251.
# WRKLIM31 dropped: structurally missing for most adults.
limitation_indicator_vars = [
    "WLKLIM31",
    "ACTLIM31",
    "SOCLIM31",
    "COGLIM31",
]

physical_difficulty_vars = [
    "DFHEAR42",
    "DFSEE42",
    "DFCOG42",
    "DFWLKC42",
    "DFDRSB42",
    "DFERND42",
]

# ANYLMI23 is a derived any-limitation summary; kept as its own predictor and
# excluded from the limitation_indicator count to avoid mechanical double-counting.
functioning_vars = limitation_indicator_vars + physical_difficulty_vars + ["ANYLMI23"]

insurance_access_vars = [
    "INSCOPE",
    "INSC1231",
    "HAVEUS42",
    "OFFER31X",
    "HELD31X",
]

# Cost-related access-barrier variables. In Part I (NHIS) these were the target.
# In Part II they are kept as predictors / descriptive access variables.
access_barrier_vars = [
    "DLAYCA42",
    "AFRDCA42",
    "DLAYPM42",
    "AFRDPM42",
    "DLAYDN42",
    "AFRDDN42",
]

candidate_vars = (
    id_design_vars
    + target_vars
    + demographic_vars
    + income_vars
    + health_need_vars
    + saq_mental_health_vars
    + functioning_vars
    + insurance_access_vars
    + access_barrier_vars
)

candidate_vars = list(dict.fromkeys(candidate_vars))

missing_candidate_vars = [col for col in candidate_vars if col not in clean_target_meps.columns]
available_candidate_vars = [col for col in candidate_vars if col in clean_target_meps.columns]

print("Candidate variables requested:", len(candidate_vars))
print("Candidate variables available:", len(available_candidate_vars))
print("Candidate variables missing:", len(missing_candidate_vars))

if missing_candidate_vars:
    print("\nMissing variables:")
    print(missing_candidate_vars)
# Out:
# Candidate variables requested: 58
# Candidate variables available: 58
# Candidate variables missing: 0

# %% [markdown]
# ## First analytic subset
#
# The first subset keeps only the target, identifiers needed for merging or survey-aware checks, and the first set of candidate predictors. The survey weight and design variables are retained in the file but will not be used as model predictors.

# %%
meps_first_pass = clean_target_meps[available_candidate_vars].copy()

print("First-pass MEPS shape:", meps_first_pass.shape)
meps_first_pass.head()
# Out:
# First-pass MEPS shape: (15123, 58)
#      DUPERSID  PANEL  DATAYEAR      PERWT23F  VARSTR  VARPSU  TOTEXP23  \
# 0  2790002101     27      2023  11664.426815    2019       1       646
# 1  2790002102     27      2023  32212.113596    2019       1      1894
# 2  2790004101     27      2023  21944.142826    2084       1       986
# 3  2790006101     27      2023  10328.009530    2113       1      1312
# 4  2790006102     27      2023  17430.521357    2113       1         0
#
#    TOTEXP23_log1p  AGE23X  SEX  ...  INSC1231  HAVEUS42  OFFER31X  HELD31X  \
# 0        6.472346      58    2  ...         1         1         1        1
# 1        7.546974      27    1  ...         1         2         1        1
# 2        6.894670      49    2  ...         1         1         1        1
# 3        7.180070      75    2  ...         1         1        -1       -1
# 4        0.000000      23    1  ...         1         2         2        2
#
#    DLAYCA42  AFRDCA42  DLAYPM42  AFRDPM42  DLAYDN42  AFRDDN42
# 0         2         2         2         2         1         1
# 1         2         2         2         2         2         2
# 2         2         2         2         2         2         2
# 3         2         2         2         2         1         1
# 4         2         2         2         2         2         2
#
# [5 rows x 58 columns]

# %% [markdown]
# ## Missingness overview
#
# Missingness in MEPS comes from several sources: true missing data, skip patterns, and reserved response codes. The first overview checks standard missing values already stored as `NaN`. Reserved codes are handled separately after the value distributions are reviewed.

# %%
missing_summary = (
    meps_first_pass
    .isna()
    .sum()
    .reset_index()
    .rename(columns={"index": "variable", 0: "missing_count"})
)

missing_summary["missing_rate"] = missing_summary["missing_count"] / len(meps_first_pass)

missing_summary = missing_summary.sort_values("missing_rate", ascending=False)

missing_summary.head(25)
# Out:
#           variable  missing_count  missing_rate
# 0         DUPERSID              0           0.0
# 1            PANEL              0           0.0
# 2         DATAYEAR              0           0.0
# 3         PERWT23F              0           0.0
# 4           VARSTR              0           0.0
# 5           VARPSU              0           0.0
# 6         TOTEXP23              0           0.0
# 7   TOTEXP23_log1p              0           0.0
# 8           AGE23X              0           0.0
# 9              SEX              0           0.0
# 10         RACETHX              0           0.0
# 11         HISPANX              0           0.0
# 12        MARRY23X              0           0.0
# 13        REGION23              0           0.0
# 14          EDUCYR              0           0.0
# 15           HIDEG              0           0.0
# 16         BORNUSA              0           0.0
# 17        FAMSZEYR              0           0.0
# 18        POVCAT23              0           0.0
# 19        POVLEV23              0           0.0
# 20        FOODST23              0           0.0
# 21        RTHLTH42              0           0.0
# 22        MNHLTH42              0           0.0
# 23          HIBPDX              0           0.0
# 24          CHOLDX              0           0.0

# %%
# Plot the top-25 variables by NaN missing rate to see distribution at a glance.
top_missing = missing_summary.head(25)

fig, ax = plt.subplots(figsize=(8, 7))
ax.barh(top_missing["variable"], top_missing["missing_rate"], color="#55A868")
ax.invert_yaxis()
ax.set_xlabel("Missing rate (NaN only, before reserved-code handling)")
ax.set_title("Top 25 candidate variables by missingness (adults)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Value checks for candidate variables
#
# The next tables show the raw value counts for the candidate variables. These checks help identify sparse variables, skip-pattern variables, and reserved response codes before any recoding is applied. In MEPS the negative reserved values (`-1`, `-7`, `-8`, `-9`, `-15`) appear directly in these counts, which makes them easy to spot.

# %%
def show_value_counts(df, columns, max_unique=20):
    for col in columns:
        if col not in df.columns:
            continue

        unique_count = df[col].nunique(dropna=False)
        print("\n" + "=" * 80)
        print(f"{col} | unique values: {unique_count}")

        if unique_count <= max_unique:
            print(df[col].value_counts(dropna=False).sort_index())
        else:
            print(df[col].describe())


review_groups = {
    "Target": target_vars,
    "Demographics": demographic_vars,
    "Income": income_vars,
    "Health need (non-SAQ)": health_need_vars,
    "Health need (SAQ - sensitivity only)": saq_mental_health_vars,
    "Functioning - limitation indicators": limitation_indicator_vars + ["ANYLMI23"],
    "Functioning - serious difficulty": physical_difficulty_vars,
    "Insurance and access": insurance_access_vars,
    "Access barriers (predictors)": access_barrier_vars,
}

for group_name, cols in review_groups.items():
    print("\n\n" + "#" * 100)
    print(group_name)
    print("#" * 100)
    show_value_counts(meps_first_pass, cols)
# Out:
# ####################################################################################################
# Target
# ####################################################################################################
#
# ================================================================================
# TOTEXP23 | unique values: 8362
# count     15123.000000
# mean       9634.878728
# std       23302.553321
# min           0.000000
# 25%         399.000000
# 50%        2458.000000
# 75%        8714.500000
# max      574675.000000
# Name: TOTEXP23, dtype: float64
#
# ================================================================================
# TOTEXP23_log1p | unique values: 8362
# count    15123.000000
# mean         6.941272
# std          3.202384
# min          0.000000
# 25%          5.991465
# 50%          7.807510
# 75%          9.072858
# max         13.261562
# Name: TOTEXP23_log1p, dtype: float64
#
#
# ####################################################################################################
# Demographics
# ####################################################################################################
#
# ================================================================================
# AGE23X | unique values: 68
# count    15123.000000
# mean        51.835086
# std         18.629300
# min         18.000000
# 25%         36.000000
# 50%         53.000000
# 75%         67.000000
# max         85.000000
# Name: AGE23X, dtype: float64
#
# ================================================================================
# SEX | unique values: 2
# SEX
# 1    7062
# 2    8061
# Name: count, dtype: int64
#
# ================================================================================
# RACETHX | unique values: 5
# RACETHX
# 1    3079
# 2    8696
# 3    1970
# 4     924
# 5     454
# Name: count, dtype: int64
#
# ================================================================================
# HISPANX | unique values: 2
# HISPANX
# 1     3079
# 2    12044
# Name: count, dtype: int64
#
# ================================================================================
# MARRY23X | unique values: 7
# MARRY23X
# -8       1
# -7       5
#  1    7497
#  2    1260
#  3    1934
#  4     342
#  5    4084
# Name: count, dtype: int64
#
# ================================================================================
# REGION23 | unique values: 4
# REGION23
# 1    2393
# 2    3063
# 3    5871
# 4    3796
# Name: count, dtype: int64
#
# ================================================================================
# EDUCYR | unique values: 20
# EDUCYR
# -8      117
# -7       32
#  0       43
#  1       45
#  2       54
#  3       57
#  4       58
#  5       50
#  6      186
#  7       71
#  8      223
#  9      305
#  10     384
#  11     593
#  12    4450
#  13     864
#  14    1848
#  15     459
#  16    3007
#  17    2277
# Name: count, dtype: int64
#
# ================================================================================
# HIDEG | unique values: 9
# HIDEG
# -8     114
# -7      34
#  1    1946
#  2     596
#  3    5657
#  4    3109
#  5    1589
#  6     535
#  7    1543
# Name: count, dtype: int64
#
# ================================================================================
# BORNUSA | unique values: 4
# BORNUSA
# -8        6
# -7       28
#  1    12112
#  2     2977
# Name: count, dtype: int64
#
# ================================================================================
# FAMSZEYR | unique values: 12
# FAMSZEYR
# 1     3303
# 2     5237
# 3     2432
# 4     2288
# 5     1034
# 6      491
# 7      195
# 8       74
# 9       35
# 10      15
# 11      11
# 14       8
# Name: count, dtype: int64
#
#
# ####################################################################################################
# Income
# ####################################################################################################
#
# ================================================================================
# POVCAT23 | unique values: 5
# POVCAT23
# 1    2074
# 2     658
# 3    1866
# 4    4250
# 5    6275
# Name: count, dtype: int64
#
# ================================================================================
# POVLEV23 | unique values: 7175
# count    15123.000000
# mean       441.682907
# std        404.487366
# min         -1.570000
# 25%        167.830000
# 50%        333.270000
# 75%        589.570000
# max       4009.820000
# Name: POVLEV23, dtype: float64
#
# ================================================================================
# FOODST23 | unique values: 4
# FOODST23
# -8       76
# -7      446
#  1     1835
#  2    12766
# Name: count, dtype: int64
#
#
# ####################################################################################################
# Health need (non-SAQ)
# ####################################################################################################
#
# ================================================================================
# RTHLTH42 | unique values: 8
# RTHLTH42
# -8      21
# -7      27
# -1      56
#  1    2997
#  2    5019
#  3    4750
#  4    1811
#  5     442
# Name: count, dtype: int64
#
# ================================================================================
# MNHLTH42 | unique values: 8
# MNHLTH42
# -8      24
# -7      30
# -1      56
#  1    3960
#  2    4714
#  3    4635
#  4    1407
#  5     297
# Name: count, dtype: int64
#
# ================================================================================
# HIBPDX | unique values: 5
# HIBPDX
# -8      28
# -7      11
# -1     105
#  1    5602
#  2    9377
# Name: count, dtype: int64
#
# ================================================================================
# CHOLDX | unique values: 5
# CHOLDX
# -8      37
# -7      12
# -1     105
#  1    5319
#  2    9650
# Name: count, dtype: int64
#
# ================================================================================
# DIABDX_M18 | unique values: 5
# DIABDX_M18
# -8       17
# -7       11
# -1       26
#  1     2104
#  2    12965
# Name: count, dtype: int64
#
# ================================================================================
# ASTHDX | unique values: 5
# ASTHDX
# -8       18
# -7       11
# -1       26
#  1     2101
#  2    12967
# Name: count, dtype: int64
#
# ================================================================================
# ARTHDX | unique values: 5
# ARTHDX
# -8       25
# -7       11
# -1      105
#  1     4382
#  2    10600
# Name: count, dtype: int64
#
# ================================================================================
# CANCERDX | unique values: 6
# CANCERDX
# -15        1
# -8        20
# -7        11
# -1       105
#  1      2047
#  2     12939
# Name: count, dtype: int64
#
# ================================================================================
# CHDDX | unique values: 5
# CHDDX
# -8       21
# -7       11
# -1      105
#  1      857
#  2    14129
# Name: count, dtype: int64
#
# ================================================================================
# STRKDX | unique values: 5
# STRKDX
# -8       16
# -7       13
# -1      105
#  1      713
#  2    14276
# Name: count, dtype: int64
#
# ================================================================================
# EMPHDX | unique values: 5
# EMPHDX
# -8       18
# -7       11
# -1      105
#  1      252
#  2    14737
# Name: count, dtype: int64
#
#
# ####################################################################################################
# Health need (SAQ - sensitivity only)
# ####################################################################################################
#
# ================================================================================
# K6SUM42 | unique values: 27
# count    15123.000000
# mean         1.199431
# std          4.686498
# min        -15.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          3.000000
# max         24.000000
# Name: K6SUM42, dtype: float64
#
# ================================================================================
# PHQ242 | unique values: 9
# PHQ242
# -15     364
# -1     5347
#  0     6538
#  1      965
#  2     1093
#  3      291
#  4      293
#  5      100
#  6      132
# Name: count, dtype: int64
#
# ================================================================================
# ADINTR42 | unique values: 6
# ADINTR42
# -15     331
# -1     5347
#  0     7008
#  1     1641
#  2      522
#  3      274
# Name: count, dtype: int64
#
# ================================================================================
# ADDPRS42 | unique values: 6
# ADDPRS42
# -15     353
# -1     5347
#  0     7201
#  1     1620
#  2      400
#  3      202
# Name: count, dtype: int64
#
#
# ####################################################################################################
# Functioning - limitation indicators
# ####################################################################################################
#
# ================================================================================
# WLKLIM31 | unique values: 5
# WLKLIM31
# -8        8
# -7       20
# -1      154
#  1     2263
#  2    12678
# Name: count, dtype: int64
#
# ================================================================================
# ACTLIM31 | unique values: 5
# ACTLIM31
# -8        8
# -7       28
# -1      154
#  1     1697
#  2    13236
# Name: count, dtype: int64
#
# ================================================================================
# SOCLIM31 | unique values: 5
# SOCLIM31
# -8       20
# -7       29
# -1      154
#  1     1006
#  2    13914
# Name: count, dtype: int64
#
# ================================================================================
# COGLIM31 | unique values: 4
# COGLIM31
# -8       30
# -1      304
#  1     1007
#  2    13782
# Name: count, dtype: int64
#
# ================================================================================
# ANYLMI23 | unique values: 4
# ANYLMI23
# -15      155
# -1        55
#  1      3416
#  2     11497
# Name: count, dtype: int64
#
#
# ####################################################################################################
# Functioning - serious difficulty
# ####################################################################################################
#
# ================================================================================
# DFHEAR42 | unique values: 5
# DFHEAR42
# -8        4
# -7        3
# -1       56
#  1      930
#  2    14130
# Name: count, dtype: int64
#
# ================================================================================
# DFSEE42 | unique values: 5
# DFSEE42
# -8        1
# -7        4
# -1       56
#  1      440
#  2    14622
# Name: count, dtype: int64
#
# ================================================================================
# DFCOG42 | unique values: 5
# DFCOG42
# -8       10
# -7        5
# -1       56
#  1     1112
#  2    13940
# Name: count, dtype: int64
#
# ================================================================================
# DFWLKC42 | unique values: 5
# DFWLKC42
# -8        7
# -7        2
# -1       56
#  1     1641
#  2    13417
# Name: count, dtype: int64
#
# ================================================================================
# DFDRSB42 | unique values: 5
# DFDRSB42
# -8        9
# -7        4
# -1       56
#  1      466
#  2    14588
# Name: count, dtype: int64
#
# ================================================================================
# DFERND42 | unique values: 5
# DFERND42
# -8        1
# -7       10
# -1       56
#  1      928
#  2    14128
# Name: count, dtype: int64
#
#
# ####################################################################################################
# Insurance and access
# ####################################################################################################
#
# ================================================================================
# INSCOPE | unique values: 2
# INSCOPE
# 1    15105
# 2       18
# Name: count, dtype: int64
#
# ================================================================================
# INSC1231 | unique values: 2
# INSC1231
# 1    15044
# 2       79
# Name: count, dtype: int64
#
# ================================================================================
# HAVEUS42 | unique values: 5
# HAVEUS42
# -8      371
# -7      243
# -1       59
#  1    10535
#  2     3915
# Name: count, dtype: int64
#
# ================================================================================
# OFFER31X | unique values: 6
# OFFER31X
# -15     508
# -8      102
# -7        3
# -1     7019
#  1     5089
#  2     2402
# Name: count, dtype: int64
#
# ================================================================================
# HELD31X | unique values: 6
# HELD31X
# -15     293
# -8       97
# -7       22
# -1     7019
#  1     3944
#  2     3748
# Name: count, dtype: int64
#
#
# ####################################################################################################
# Access barriers (predictors)
# ####################################################################################################
#
# ================================================================================
# DLAYCA42 | unique values: 5
# DLAYCA42
# -8       27
# -7       37
# -1       59
#  1     1088
#  2    13912
# Name: count, dtype: int64
#
# ================================================================================
# AFRDCA42 | unique values: 5
# AFRDCA42
# -8       21
# -7       36
# -1       59
#  1      597
#  2    14410
# Name: count, dtype: int64
#
# ================================================================================
# DLAYPM42 | unique values: 5
# DLAYPM42
# -8       18
# -7       28
# -1       59
#  1      548
#  2    14470
# Name: count, dtype: int64
#
# ================================================================================
# AFRDPM42 | unique values: 5
# AFRDPM42
# -8       20
# -7       28
# -1       59
#  1      489
#  2    14527
# Name: count, dtype: int64
#
# ================================================================================
# DLAYDN42 | unique values: 5
# DLAYDN42
# -8       13
# -7       27
# -1       59
#  1     2064
#  2    12960
# Name: count, dtype: int64
#
# ================================================================================
# AFRDDN42 | unique values: 5
# AFRDDN42
# -8       18
# -7       27
# -1       59
#  1     1441
#  2    13578
# Name: count, dtype: int64

# %% [markdown]
# ## Simple distribution and target-relationship plots (raw codes, adults)
#
# Quick distribution plots help confirm that key predictors look reasonable against the codebook. Age starts at 18 in this adult-only frame; perceived mental-health status (`MNHLTH42`) should run from 1 (Excellent) to 5 (Poor) with reserved negatives; the K6 score (`K6SUM42`) ranges from 0 to 24 with `-1` for inapplicable and `-15` for cannot-be-computed cases.
#
# These plots are computed before reserved-code cleaning, so reserved codes (`-15`, `-8`, `-7`, `-1`) appear as their own bars. They are useful as a data-quality check, not as a substantive read on the predictor → spending relationship — that comes after reserved-code cleaning a few cells below.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Age distribution (adult range starts at 18).
if "AGE23X" in meps_first_pass.columns:
    age_clean = meps_first_pass["AGE23X"].dropna()
    axes[0].hist(age_clean, bins=20, color="#4C72B0", edgecolor="white")
    axes[0].set_title("Age (AGE23X), adults")
    axes[0].set_xlabel("age")
    axes[0].set_ylabel("count")

# Perceived mental health status (1=Excellent ... 5=Poor; negatives are reserved).
if "MNHLTH42" in meps_first_pass.columns:
    mh_counts = meps_first_pass["MNHLTH42"].value_counts(dropna=False).sort_index()
    axes[1].bar(mh_counts.index.astype(str), mh_counts.values, color="#DD8452")
    axes[1].set_title("Perceived mental health (MNHLTH42, raw)")
    axes[1].set_xlabel("value (raw, includes reserved codes)")
    axes[1].set_ylabel("count")

# K6 score distribution.
if "K6SUM42" in meps_first_pass.columns:
    k6_counts = meps_first_pass["K6SUM42"].value_counts(dropna=False).sort_index()
    axes[2].bar(k6_counts.index.astype(str), k6_counts.values, color="#55A868")
    axes[2].set_title("Kessler-6 score (K6SUM42, raw)")
    axes[2].set_xlabel("value (raw, includes reserved codes)")
    axes[2].set_ylabel("count")
    for label in axes[2].get_xticklabels():
        label.set_rotation(90)

plt.tight_layout()
plt.show()

# %%
# Mean log1p spending by 10-year age band - basic age gradient sanity check.
# Adult-only file means the lowest band starts at 18.
if "AGE23X" in meps_first_pass.columns:
    age_bins = pd.cut(
        meps_first_pass["AGE23X"],
        bins=[17, 24, 34, 44, 54, 64, 74, 120],
        labels=["18-24", "25-34", "35-44", "45-54", "55-64", "65-74", "75+"],
    )
    spend_by_age = (
        meps_first_pass.assign(age_bin=age_bins)
        .groupby("age_bin", observed=True)["TOTEXP23_log1p"]
        .agg(["mean", "count"])
        .rename(columns={"mean": "mean_log1p_spend", "count": "n"})
    )
    print(spend_by_age.round(2))

    fig, ax = plt.subplots(figsize=(7, 4))
    ax.bar(spend_by_age.index.astype(str), spend_by_age["mean_log1p_spend"], color="#4C72B0")
    ax.set_title("Mean log1p(TOTEXP23) by age band, adults")
    ax.set_xlabel("age band")
    ax.set_ylabel("mean log1p(TOTEXP23)")
    plt.tight_layout()
    plt.show()
# Out:
#          mean_log1p_spend     n
# age_bin
# 18-24                4.86  1279
# 25-34                5.55  2075
# 35-44                6.10  2406
# 45-54                6.71  2223
# 55-64                7.48  2601
# 65-74                8.22  2589
# 75+                  8.67  1950

# %% [markdown]
# ## Reserved code cleaning rules
#
# MEPS uses negative reserved response codes for values such as inapplicable, refused, don't know, not ascertained, and cannot be computed. Unlike NHIS, where reserved codes can collide with valid category numbers, MEPS reserved codes are negative and therefore safe to recode in one consistent rule for nominal/ordinal categorical variables.
#
# Two cautions:
#
# 1. Continuous variables that can legitimately take zero or small positive values (income, K6 score, age) must be recoded carefully — `-1` and `-15` are reserved, but `0` is a real value.
# 2. The K6 score (`K6SUM42`) and PHQ-2 score (`PHQ242`) use `-1 = INAPPLICABLE` and `-15 = CANNOT BE COMPUTED`; everything else is a true score (0 through 24 for K6).
# 3. The target `TOTEXP23` is left unchanged here — it is a constructed dollar field with no reserved codes.

# %%
meps_clean_step1 = meps_first_pass.copy()

# Negative reserved codes used in MEPS HC-251.
reserved_codes_meps = [-1, -7, -8, -9, -15]

categorical_recode_vars = [
    "SEX",
    "RACETHX",
    "HISPANX",
    "MARRY23X",
    "REGION23",
    "HIDEG",
    "BORNUSA",
    "RTHLTH42",
    "MNHLTH42",
    "ADINTR42",
    "ADDPRS42",
    "HIBPDX",
    "CHOLDX",
    "DIABDX_M18",
    "ASTHDX",
    "ARTHDX",
    "CANCERDX",
    "CHDDX",
    "STRKDX",
    "EMPHDX",
    # Limitation indicators (WRKLIM31 dropped from candidates above).
    "WLKLIM31",
    "ACTLIM31",
    "SOCLIM31",
    "COGLIM31",
    "DFHEAR42",
    "DFSEE42",
    "DFCOG42",
    "DFWLKC42",
    "DFDRSB42",
    "DFERND42",
    "ANYLMI23",
    "INSCOPE",
    "INSC1231",
    "HAVEUS42",
    "DLAYCA42",
    "AFRDCA42",
    "DLAYPM42",
    "AFRDPM42",
    "DLAYDN42",
    "AFRDDN42",
    "OFFER31X",
    "HELD31X",
    "FOODST23",
    "POVCAT23",
]

for col in categorical_recode_vars:
    if col in meps_clean_step1.columns:
        meps_clean_step1[col] = meps_clean_step1[col].replace(
            {code: np.nan for code in reserved_codes_meps}
        )

# Score and continuous variables: recode reserved codes only, keep zeros.
score_continuous_vars = [
    "AGE23X",
    "EDUCYR",
    "FAMSZEYR",
    "K6SUM42",
    "PHQ242",
    "POVLEV23",
]

for col in score_continuous_vars:
    if col in meps_clean_step1.columns:
        meps_clean_step1[col] = meps_clean_step1[col].replace(
            {code: np.nan for code in reserved_codes_meps}
        )

print("Reserved-code cleaning complete.")
# Out:
# Reserved-code cleaning complete.

# %% [markdown]
# ## Mental-health relationship plots after reserved-code cleaning
#
# Repeat the `MNHLTH42` and `K6SUM42` relationship views using the cleaned frame. Now that the negative reserved codes (`-15`, `-8`, `-7`, `-1`) have been mapped to `NaN`, only valid response categories remain — `MNHLTH42` runs 1 (Excellent) to 5 (Poor), and `K6SUM42` runs 0 to 24. These post-cleaning plots are the ones to read substantively; the earlier raw-code plots were only data-quality checks.
#
# Note that `K6SUM42` is a SAQ variable, so it is shown here as part of the EDA but is not in the primary model-ready file (it goes to the sensitivity file).

# %%
# Mean log1p spending by perceived mental health status, valid codes only.
if "MNHLTH42" in meps_clean_step1.columns:
    spend_by_mh = (
        meps_clean_step1.dropna(subset=["MNHLTH42"])
        .groupby("MNHLTH42")
        .agg(
            mean_log1p_spend=("TOTEXP23_log1p", "mean"),
            mean_raw_spend=("TOTEXP23", "mean"),
            n=("TOTEXP23", "size"),
        )
        .sort_index()
    )
    mh_labels = {1: "1 Excellent", 2: "2 Very good", 3: "3 Good", 4: "4 Fair", 5: "5 Poor"}
    print(spend_by_mh.round(2))

    fig, ax = plt.subplots(figsize=(7, 4))
    x_labels = [mh_labels.get(int(v), str(v)) for v in spend_by_mh.index]
    ax.bar(x_labels, spend_by_mh["mean_log1p_spend"], color="#C44E52")
    ax.set_title("Mean log1p(TOTEXP23) by perceived mental health (valid codes only)")
    ax.set_xlabel("MNHLTH42")
    ax.set_ylabel("mean log1p(TOTEXP23)")
    plt.tight_layout()
    plt.show()
# Out:
#           mean_log1p_spend  mean_raw_spend     n
# MNHLTH42
# 1.0                   6.54         7432.25  3960
# 2.0                   6.97         8213.72  4714
# 3.0                   7.03        10783.38  4635
# 4.0                   7.74        14954.29  1407
# 5.0                   8.23        21327.90   297

# %%
# Mean log1p spending by K6 band, valid codes only.
# K6 thresholds in common use: 0-4 no/low distress, 5-12 moderate, 13-24 serious.
if "K6SUM42" in meps_clean_step1.columns:
    k6_clean = meps_clean_step1.dropna(subset=["K6SUM42"]).copy()
    k6_clean["k6_band"] = pd.cut(
        k6_clean["K6SUM42"],
        bins=[-0.1, 4, 12, 24],
        labels=["0-4 (low)", "5-12 (moderate)", "13-24 (serious)"],
    )
    spend_by_k6 = (
        k6_clean.groupby("k6_band", observed=True)["TOTEXP23_log1p"]
        .agg(["mean", "count"])
        .rename(columns={"mean": "mean_log1p_spend", "count": "n"})
    )
    print(spend_by_k6.round(2))

    fig, ax = plt.subplots(figsize=(7, 4))
    ax.bar(spend_by_k6.index.astype(str), spend_by_k6["mean_log1p_spend"], color="#8172B2")
    ax.set_title("Mean log1p(TOTEXP23) by K6 distress band (SAQ subframe only)")
    ax.set_xlabel("K6 score band")
    ax.set_ylabel("mean log1p(TOTEXP23)")
    plt.tight_layout()
    plt.show()
# Out:
#                  mean_log1p_spend     n
# k6_band
# 0-4 (low)                    7.27  7032
# 5-12 (moderate)              7.96  1899
# 13-24 (serious)              8.19   424

# %% [markdown]
# ## Missingness after reserved-code recoding
#
# The updated missingness table shows how much information is lost after reserved codes are treated as missing. Variables with heavy missingness will need a keep/drop decision before modeling — the K6 score, for example, is collected only on adult SAQ respondents, so it carries a structurally large `INAPPLICABLE` share. This is exactly the reason the SAQ variables go into the sensitivity model-ready file rather than the primary one.

# %%
missing_after_reserved = (
    meps_clean_step1
    .isna()
    .sum()
    .reset_index()
    .rename(columns={"index": "variable", 0: "missing_count"})
)

missing_after_reserved["missing_rate"] = missing_after_reserved["missing_count"] / len(meps_clean_step1)

missing_after_reserved = missing_after_reserved.sort_values("missing_rate", ascending=False)

missing_after_reserved.head(30)
# Out:
#     variable  missing_count  missing_rate
# 50  OFFER31X           7632      0.504662
# 51   HELD31X           7431      0.491371
# 32   K6SUM42           5768      0.381406
# 33    PHQ242           5711      0.377637
# 35  ADDPRS42           5700      0.376909
# 34  ADINTR42           5678      0.375455
# 49  HAVEUS42            673      0.044502
# 20  FOODST23            522      0.034517
# 39  COGLIM31            334      0.022086
# 46  ANYLMI23            210      0.013886
# 38  SOCLIM31            203      0.013423
# 37  ACTLIM31            190      0.012564
# 36  WLKLIM31            182      0.012035
# 24    CHOLDX            154      0.010183
# 14    EDUCYR            149      0.009853
# 15     HIDEG            148      0.009786
# 23    HIBPDX            144      0.009522
# 27    ARTHDX            141      0.009324
# 28  CANCERDX            137      0.009059
# 29     CHDDX            137      0.009059
# 31    EMPHDX            134      0.008861
# 30    STRKDX            134      0.008861
# 52  DLAYCA42            123      0.008133
# 53  AFRDCA42            116      0.007670
# 22  MNHLTH42            110      0.007274
# 55  AFRDPM42            107      0.007075
# 54  DLAYPM42            105      0.006943
# 57  AFRDDN42            104      0.006877
# 21  RTHLTH42            104      0.006877
# 56  DLAYDN42             99      0.006546

# %% [markdown]
# ## Initial keep/drop review table
#
# The first review table does not make final decisions. It gives a compact view of each candidate variable, its missing rate, and a starter decision. Final decisions should use the codebook, EDA, and modeling purpose together.
#
# For the Part II regression the keep/drop logic is:
#
# **Keep for the primary model-ready file:** demographics, `POVCAT23` (primary poverty feature), non-SAQ health need (perceived health, chronic conditions), functioning/disability indicators (excluding `WRKLIM31`), insurance status, access (usual source of care), and the cost-related access barriers as predictors.
#
# **Sensitivity-only (saved separately as `meps_model_ready_v1_with_saq.csv`):** the SAQ mental-health variables `K6SUM42`, `PHQ242`, `ADINTR42`, `ADDPRS42`, plus the engineered `mental_health_screen_count`.
#
# **Drop from both model-ready files:**
# - Identifiers (`DUPERSID`, `PANEL`, `DATAYEAR`).
# - Survey weights and design variables (`PERWT23F`, `VARSTR`, `VARPSU`) — kept available in interim files but not used as predictors.
# - `POVLEV23` — collinear with `POVCAT23`. Kept in the interim file for sensitivity analyses.
# - `WRKLIM31` — structurally missing for adults.
# - All other dollar expenditure variables (`TOTSLF23`, `TOTMCR23`, `TOTMCD23`, `RXEXP23`, `OBVEXP23`, ...) and event-count variables (`OBTOTV23`, `RXTOT23`, `IPDIS23`, ...) — these mechanically determine `TOTEXP23` and would leak the target.
#
# We do not include those leakage variables in `candidate_vars` above, but the next section also enforces the drop programmatically against the *full* MEPS column list so a future expansion of the candidate set cannot accidentally re-introduce them.

# %%
variable_roles = {}

for col in id_design_vars:
    variable_roles[col] = "identifier/design"
for col in target_vars:
    variable_roles[col] = "target/documentation"
for col in demographic_vars:
    variable_roles[col] = "demographic"
for col in income_vars:
    variable_roles[col] = "income/poverty"
for col in health_need_vars:
    variable_roles[col] = "health need (non-SAQ)"
for col in saq_mental_health_vars:
    variable_roles[col] = "health need (SAQ)"
for col in functioning_vars:
    variable_roles[col] = "functioning/disability"
for col in insurance_access_vars:
    variable_roles[col] = "insurance/access"
for col in access_barrier_vars:
    variable_roles[col] = "access barrier (predictor)"

review_table = missing_after_reserved.copy()
review_table["role"] = review_table["variable"].map(variable_roles).fillna("unassigned")

def starter_decision(row):
    variable = row["variable"]
    missing_rate = row["missing_rate"]

    if variable in ["DUPERSID", "PANEL", "DATAYEAR", "PERWT23F", "VARSTR", "VARPSU"]:
        return "keep for merge/EDA, exclude from model predictors"

    if variable == "TOTEXP23":
        return "target (raw)"

    if variable == "TOTEXP23_log1p":
        return "target (log1p sensitivity)"

    if variable == "POVLEV23":
        return "keep in interim only; sensitivity option for POVCAT23"

    if variable in saq_mental_health_vars:
        return "sensitivity model-ready file only (SAQ subframe)"

    if missing_rate >= 0.60:
        return "review; likely drop or subgroup only"

    if missing_rate >= 0.30:
        return "review before modeling"

    return "candidate predictor"

review_table["starter_decision"] = review_table.apply(starter_decision, axis=1)

review_table = review_table[
    ["variable", "role", "missing_count", "missing_rate", "starter_decision"]
].sort_values(["starter_decision", "missing_rate"], ascending=[True, False])

review_table
# Out:
#           variable                        role  missing_count  missing_rate  \
# 49        HAVEUS42            insurance/access            673      0.044502
# 20        FOODST23              income/poverty            522      0.034517
# 39        COGLIM31      functioning/disability            334      0.022086
# 46        ANYLMI23      functioning/disability            210      0.013886
# 38        SOCLIM31      functioning/disability            203      0.013423
# 37        ACTLIM31      functioning/disability            190      0.012564
# 36        WLKLIM31      functioning/disability            182      0.012035
# 24          CHOLDX       health need (non-SAQ)            154      0.010183
# 14          EDUCYR                 demographic            149      0.009853
# 15           HIDEG                 demographic            148      0.009786
# 23          HIBPDX       health need (non-SAQ)            144      0.009522
# 27          ARTHDX       health need (non-SAQ)            141      0.009324
# 28        CANCERDX       health need (non-SAQ)            137      0.009059
# 29           CHDDX       health need (non-SAQ)            137      0.009059
# 31          EMPHDX       health need (non-SAQ)            134      0.008861
# 30          STRKDX       health need (non-SAQ)            134      0.008861
# 52        DLAYCA42  access barrier (predictor)            123      0.008133
# 53        AFRDCA42  access barrier (predictor)            116      0.007670
# 22        MNHLTH42       health need (non-SAQ)            110      0.007274
# 55        AFRDPM42  access barrier (predictor)            107      0.007075
# 54        DLAYPM42  access barrier (predictor)            105      0.006943
# 57        AFRDDN42  access barrier (predictor)            104      0.006877
# 21        RTHLTH42       health need (non-SAQ)            104      0.006877
# 56        DLAYDN42  access barrier (predictor)             99      0.006546
# 42         DFCOG42      functioning/disability             71      0.004695
# 44        DFDRSB42      functioning/disability             69      0.004563
# 45        DFERND42      functioning/disability             67      0.004430
# 43        DFWLKC42      functioning/disability             65      0.004298
# 40        DFHEAR42      functioning/disability             63      0.004166
# 41         DFSEE42      functioning/disability             61      0.004034
# 26          ASTHDX       health need (non-SAQ)             55      0.003637
# 25      DIABDX_M18       health need (non-SAQ)             54      0.003571
# 16         BORNUSA                 demographic             34      0.002248
# 12        MARRY23X                 demographic              6      0.000397
# 8           AGE23X                 demographic              0      0.000000
# 9              SEX                 demographic              0      0.000000
# 18        POVCAT23              income/poverty              0      0.000000
# 10         RACETHX                 demographic              0      0.000000
# 17        FAMSZEYR                 demographic              0      0.000000
# 13        REGION23                 demographic              0      0.000000
# 11         HISPANX                 demographic              0      0.000000
# 48        INSC1231            insurance/access              0      0.000000
# 47         INSCOPE            insurance/access              0      0.000000
# 0         DUPERSID           identifier/design              0      0.000000
# 1            PANEL           identifier/design              0      0.000000
# 2         DATAYEAR           identifier/design              0      0.000000
# 3         PERWT23F           identifier/design              0      0.000000
# 4           VARSTR           identifier/design              0      0.000000
# 5           VARPSU           identifier/design              0      0.000000
# 19        POVLEV23              income/poverty              0      0.000000
# 50        OFFER31X            insurance/access           7632      0.504662
# 51         HELD31X            insurance/access           7431      0.491371
# 32         K6SUM42           health need (SAQ)           5768      0.381406
# 33          PHQ242           health need (SAQ)           5711      0.377637
# 35        ADDPRS42           health need (SAQ)           5700      0.376909
# 34        ADINTR42           health need (SAQ)           5678      0.375455
# 7   TOTEXP23_log1p        target/documentation              0      0.000000
# 6         TOTEXP23        target/documentation              0      0.000000
#
#                                      starter_decision
# 49                                candidate predictor
# 20                                candidate predictor
# 39                                candidate predictor
# 46                                candidate predictor
# 38                                candidate predictor
# 37                                candidate predictor
# 36                                candidate predictor
# 24                                candidate predictor
# 14                                candidate predictor
# 15                                candidate predictor
# 23                                candidate predictor
# 27                                candidate predictor
# 28                                candidate predictor
# 29                                candidate predictor
# 31                                candidate predictor
# 30                                candidate predictor
# 52                                candidate predictor
# 53                                candidate predictor
# 22                                candidate predictor
# 55                                candidate predictor
# 54                                candidate predictor
# 57                                candidate predictor
# 21                                candidate predictor
# 56                                candidate predictor
# 42                                candidate predictor
# 44                                candidate predictor
# 45                                candidate predictor
# 43                                candidate predictor
# 40                                candidate predictor
# 41                                candidate predictor
# 26                                candidate predictor
# 25                                candidate predictor
# 16                                candidate predictor
# 12                                candidate predictor
# 8                                 candidate predictor
# 9                                 candidate predictor
# 18                                candidate predictor
# 10                                candidate predictor
# 17                                candidate predictor
# 13                                candidate predictor
# 11                                candidate predictor
# 48                                candidate predictor
# 47                                candidate predictor
# 0   keep for merge/EDA, exclude from model predictors
# 1   keep for merge/EDA, exclude from model predictors
# 2   keep for merge/EDA, exclude from model predictors
# 3   keep for merge/EDA, exclude from model predictors
# 4   keep for merge/EDA, exclude from model predictors
# 5   keep for merge/EDA, exclude from model predictors
# 19  keep in interim only; sensitivity option for P...
# 50                             review before modeling
# 51                             review before modeling
# 32   sensitivity model-ready file only (SAQ subframe)
# 33   sensitivity model-ready file only (SAQ subframe)
# 35   sensitivity model-ready file only (SAQ subframe)
# 34   sensitivity model-ready file only (SAQ subframe)
# 7                          target (log1p sensitivity)
# 6                                        target (raw)

# %% [markdown]
# ## Quick check after reserved-code cleaning
#
# Education (`EDUCYR`, `HIDEG`), age (`AGE23X`), and the K6 / PHQ-2 scores are sanity-checked here. Their post-cleaning distributions should match the codebook value lists with the reserved codes removed.

# %%
check_cols = ["AGE23X", "EDUCYR", "HIDEG", "K6SUM42", "PHQ242", "POVCAT23", "POVLEV23"]

for col in check_cols:
    if col in meps_clean_step1.columns:
        print("\n" + "=" * 80)
        print(col)
        if meps_clean_step1[col].nunique(dropna=False) <= 30:
            print(meps_clean_step1[col].value_counts(dropna=False).sort_index())
        else:
            print(meps_clean_step1[col].describe())
# Out:
# ================================================================================
# AGE23X
# count    15123.000000
# mean        51.835086
# std         18.629300
# min         18.000000
# 25%         36.000000
# 50%         53.000000
# 75%         67.000000
# max         85.000000
# Name: AGE23X, dtype: float64
#
# ================================================================================
# EDUCYR
# EDUCYR
# 0.0       43
# 1.0       45
# 2.0       54
# 3.0       57
# 4.0       58
# 5.0       50
# 6.0      186
# 7.0       71
# 8.0      223
# 9.0      305
# 10.0     384
# 11.0     593
# 12.0    4450
# 13.0     864
# 14.0    1848
# 15.0     459
# 16.0    3007
# 17.0    2277
# NaN      149
# Name: count, dtype: int64
#
# ================================================================================
# HIDEG
# HIDEG
# 1.0    1946
# 2.0     596
# 3.0    5657
# 4.0    3109
# 5.0    1589
# 6.0     535
# 7.0    1543
# NaN     148
# Name: count, dtype: int64
#
# ================================================================================
# K6SUM42
# K6SUM42
# 0.0     3089
# 1.0     1359
# 2.0     1118
# 3.0      831
# 4.0      635
# 5.0      416
# 6.0      390
# 7.0      260
# 8.0      221
# 9.0      187
# 10.0     148
# 11.0     107
# 12.0     170
# 13.0      87
# 14.0      71
# 15.0      55
# 16.0      51
# 17.0      43
# 18.0      52
# 19.0      18
# 20.0      20
# 21.0       7
# 22.0       7
# 23.0       3
# 24.0      10
# NaN     5768
# Name: count, dtype: int64
#
# ================================================================================
# PHQ242
# PHQ242
# 0.0    6538
# 1.0     965
# 2.0    1093
# 3.0     291
# 4.0     293
# 5.0     100
# 6.0     132
# NaN    5711
# Name: count, dtype: int64
#
# ================================================================================
# POVCAT23
# POVCAT23
# 1    2074
# 2     658
# 3    1866
# 4    4250
# 5    6275
# Name: count, dtype: int64
#
# ================================================================================
# POVLEV23
# count    15123.000000
# mean       441.682907
# std        404.487366
# min         -1.570000
# 25%        167.830000
# 50%        333.270000
# 75%        589.570000
# max       4009.820000
# Name: POVLEV23, dtype: float64

# %% [markdown]
# ## Save the first cleaned candidate file
#
# The saved file is still an interim file. It contains the cleaned target (raw and log1p) plus the first candidate predictors after reserved-code handling. `POVLEV23` and the SAQ variables are included here so the sensitivity flows can pull them. The next pass will refine keep/drop decisions and may bring in event-level files (medical conditions, prescribed medicines, office-based visits) as supporting layers.

# %%
output_path = DATA_INTERIM / "meps_first_pass_cleaned_candidates.csv"

meps_clean_step1.to_csv(output_path, index=False)

print("Saved:", output_path)
print("Saved shape:", meps_clean_step1.shape)
# Out:
# Saved: /content/drive/MyDrive/med_project/data/interim/meps_first_pass_cleaned_candidates.csv
# Saved shape: (15123, 58)

# %% [markdown]
# ## First model-ready variable decisions
#
# The first model-ready file should be simple enough to explain and strong enough to model. Variables with heavy skip-pattern missingness are removed from the primary file; the SAQ mental-health items move to a separate sensitivity file rather than being dropped entirely.
#
# Two cases worth flagging:
#
# - The K6 score and PHQ-2 score (`K6SUM42`, `PHQ242`, `ADINTR42`, `ADDPRS42`) come from the Self-Administered Questionnaire and are missing for everyone outside the SAQ frame. They are kept in the sensitivity file (`meps_model_ready_v1_with_saq.csv`) so an SAQ-conditioned model can use them, but they are dropped from the primary file so the headline model uses the broader adult population.
# - Round-3/1 functioning items (`WLKLIM31`, `ACTLIM31`, etc.) are observed in an earlier round. Missing values are kept as a separate `Unknown` category for the first pass.

# %%
meps_model_ready = meps_clean_step1.copy()

# %% [markdown]
# ## Create broader feature groups
#
# Some variables are useful individually, while others are easier to explain as grouped indicators. The first feature engineering pass creates simple summaries for chronic conditions, mental-health screening (SAQ-derived; only used in the sensitivity model-ready file), the two functioning sub-groups (limitation indicators vs. serious-difficulty indicators), and the cost-related access-barrier predictors.
#
# The functioning split is conceptual: `*LIM31` items are general yes/no limitation screeners, while `DF*42` items are the Census six-item disability set asking about serious difficulty in specific physical or sensory functions. Per the HC-251 codebook both groups are coded 1=YES / 2=NO, so the same `count_yes_values` helper applies to each — but they are kept as two separate features so a later analysis can tell whether broad limitations or specific physical-difficulty domains carry more predictive weight.

# %%
chronic_condition_cols = [
    "HIBPDX",
    "CHOLDX",
    "DIABDX_M18",
    "ASTHDX",
    "ARTHDX",
    "CANCERDX",
    "CHDDX",
    "STRKDX",
    "EMPHDX",
]

# SAQ PHQ-2 items - the count built from these is included only in the sensitivity
# model-ready file because the inputs are SAQ-only.
mental_health_screen_cols = [
    "ADINTR42",
    "ADDPRS42",
]

# Cost-related access-barrier indicators kept as a single "affordability pressure"
# count predictor.
access_barrier_count_cols = [
    "DLAYCA42",
    "AFRDCA42",
    "DLAYPM42",
    "AFRDPM42",
    "DLAYDN42",
    "AFRDDN42",
]

# %%
def count_yes_values(df, columns):
    available_cols = [col for col in columns if col in df.columns]
    return (df[available_cols] == 1).sum(axis=1)


def count_phq_positive(df, columns):
    # PHQ-2 items: 0=Not at all, 1=Several days, 2=More than half the days, 3=Nearly every day.
    # Score >= 2 on either item is a common positive screen marker.
    available_cols = [col for col in columns if col in df.columns]
    return df[available_cols].isin([2, 3]).sum(axis=1)


meps_model_ready["chronic_condition_count"] = count_yes_values(
    meps_model_ready,
    chronic_condition_cols
)

# Built from SAQ inputs - lives in the sensitivity model-ready file only.
meps_model_ready["mental_health_screen_count"] = count_phq_positive(
    meps_model_ready,
    mental_health_screen_cols
)

# Two separate functioning summary features.
# limitation_indicator_vars (no WRKLIM31) and physical_difficulty_vars are defined
# in the candidate-variables cell.
meps_model_ready["limitation_indicator_count"] = count_yes_values(
    meps_model_ready,
    limitation_indicator_vars
)

meps_model_ready["physical_difficulty_count"] = count_yes_values(
    meps_model_ready,
    physical_difficulty_vars
)

meps_model_ready["access_barrier_count"] = count_yes_values(
    meps_model_ready,
    access_barrier_count_cols
)

summary_cols = [
    "chronic_condition_count",
    "mental_health_screen_count",
    "limitation_indicator_count",
    "physical_difficulty_count",
    "access_barrier_count",
]

meps_model_ready[summary_cols].describe()
# Out:
#        chronic_condition_count  mental_health_screen_count  \
# count             15123.000000                15123.000000
# mean                  1.545791                    0.092442
# std                   1.617199                    0.382009
# min                   0.000000                    0.000000
# 25%                   0.000000                    0.000000
# 50%                   1.000000                    0.000000
# 75%                   3.000000                    0.000000
# max                   9.000000                    2.000000
#
#        limitation_indicator_count  physical_difficulty_count  \
# count                15123.000000               15123.000000
# mean                     0.394961                   0.364809
# std                      0.906044                   0.869867
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      4.000000                   6.000000
#
#        access_barrier_count
# count          15123.000000
# mean               0.411757
# std                1.025562
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max                6.000000

# %% [markdown]
# ## Handle selected categorical missing values
#
# For the model-ready files, missing values in selected categorical predictors are kept as explicit `"Unknown"` categories. This avoids dropping many rows and keeps skip-pattern information visible.
#
# The target is already clean, so no target rows are removed here.

# %%
categorical_missing_as_unknown = [
    "HIDEG",
    "MARRY23X",
    "BORNUSA",
    "INSC1231",
    "HAVEUS42",
    "OFFER31X",
    "HELD31X",
    "POVCAT23",
]

for col in categorical_missing_as_unknown:
    if col in meps_model_ready.columns:
        meps_model_ready[col] = meps_model_ready[col].fillna("Unknown")

# %% [markdown]
# ## Build the drop lists
#
# Three drop-list components are assembled before saving the model-ready files:
#
# 1. **Identifier and survey-design columns** — kept in interim files, never used as predictors.
# 2. **Secondary poverty (`POVLEV23`)** — collinear with `POVCAT23`, dropped from both model-ready files.
# 3. **Leakage** — every 2023 dollar expenditure column except `TOTEXP23` itself, plus mechanically related utilization counts. The rule is applied programmatically against the full MEPS column space so a future expansion cannot accidentally re-introduce a leakage column.

# %%
# Identifiers and survey design - kept in interim files, not used as predictors.
drop_id_design = [
    "DUPERSID",
    "PANEL",
    "DATAYEAR",
    "PERWT23F",
    "VARSTR",
    "VARPSU",
]

# Poverty: keep POVCAT23 as the primary feature; POVLEV23 stays in the interim
# file as a sensitivity option but is dropped here to avoid collinearity.
drop_secondary_poverty = ["POVLEV23"]

# All other dollar expenditure variables: any 2023 expenditure or payment-source
# variable by event type (TOT/OB/OP/ER/IP/HH/DV/VIS/RX/OTH) leaks the target.
# Suffixes seen in the codebook: EXP, SLF, MCR, MCD, PRV, VA, TRI, OFD, STL, WCP,
# OSR, PTR, OTH, TCH (charges).
expenditure_prefixes = (
    "TOT", "OB", "OP", "ER", "IP", "HH", "DV", "VIS", "RX", "OTH",
)
expenditure_suffixes_23 = (
    "EXP23", "SLF23", "MCR23", "MCD23", "PRV23", "VA23", "TRI23",
    "OFD23", "STL23", "WCP23", "OSR23", "PTR23", "OTH23", "TCH23",
)

def is_expenditure_var(col):
    if not col.endswith(expenditure_suffixes_23):
        return False
    return col.startswith(expenditure_prefixes)

# Utilization counts that map almost mechanically into spend.
utilization_count_vars = [
    "OBTOTV23", "OBDRV23",
    "OPTOTV23", "OPDRV23",
    "ERTOT23",
    "IPDIS23", "IPNGTD23",
    "DVTOT23",
    "HHTOTD23", "HHAGD23", "HHINDD23", "HHINFD23",
    "RXTOT23",
]

# Build the leakage drop list against the full MEPS column space.
all_meps_cols = list(meps_full.columns)
leakage_expenditure_cols = [c for c in all_meps_cols if is_expenditure_var(c) and c != "TOTEXP23"]
leakage_utilization_cols = [c for c in utilization_count_vars if c in all_meps_cols]

common_drop = (
    drop_id_design
    + drop_secondary_poverty
    + leakage_expenditure_cols
    + leakage_utilization_cols
)
common_drop = list(dict.fromkeys(common_drop))

print(f"Identifier/design columns to drop:    {len(drop_id_design)}")
print(f"Secondary poverty (POVLEV23) drop:    {len(drop_secondary_poverty)}")
print(f"Leakage expenditure cols (full file): {len(leakage_expenditure_cols)}")
print(f"Leakage utilization cols (full file): {len(leakage_utilization_cols)}")
print(f"Total in common drop list:            {len(common_drop)}")
# Out:
# Identifier/design columns to drop:    6
# Secondary poverty (POVLEV23) drop:    1
# Leakage expenditure cols (full file): 278
# Leakage utilization cols (full file): 13
# Total in common drop list:            298

# %% [markdown]
# ## Save the sensitivity model-ready file (with SAQ)
#
# The sensitivity file applies the common drop list (identifiers, survey design, `POVLEV23`, leakage) but keeps the SAQ mental-health variables (`K6SUM42`, `PHQ242`, `ADINTR42`, `ADDPRS42`) and the SAQ-derived `mental_health_screen_count`. Models trained on this file are restricted to the SAQ-eligible adult subframe (after row-level handling of SAQ missingness in the modeling notebook), but they can use the K6/PHQ-2 signal.

# %%
sensitivity_drop = [c for c in common_drop if c in meps_model_ready.columns]

meps_model_ready_with_saq = meps_model_ready.drop(columns=sensitivity_drop).copy()

sensitivity_path = DATA_PROCESSED / "meps_model_ready_v1_with_saq.csv"
meps_model_ready_with_saq.to_csv(sensitivity_path, index=False)

print(f"Sensitivity (with SAQ) shape: {meps_model_ready_with_saq.shape}")
print(f"Saved: {sensitivity_path}")
# Out:
# Sensitivity (with SAQ) shape: (15123, 56)
# Saved: /content/drive/MyDrive/med_project/data/processed/meps_model_ready_v1_with_saq.csv

# %% [markdown]
# ## Build and save the primary model-ready file (SAQ removed)
#
# The primary model-ready file additionally drops the SAQ mental-health variables and the SAQ-derived count feature, so the headline model fits on the broader adult population without an SAQ-eligibility constraint.

# %%
saq_drop = saq_mental_health_vars + ["mental_health_screen_count"]
saq_drop = [c for c in saq_drop if c in meps_model_ready_with_saq.columns]

meps_model_ready_primary = meps_model_ready_with_saq.drop(columns=saq_drop).copy()

print(f"SAQ columns dropped from primary: {saq_drop}")
print(f"Primary model-ready shape:        {meps_model_ready_primary.shape}")
print("\nPrimary model-ready columns:")
print(meps_model_ready_primary.columns.tolist())
# Out:
# SAQ columns dropped from primary: ['K6SUM42', 'PHQ242', 'ADINTR42', 'ADDPRS42', 'mental_health_screen_count']
# Primary model-ready shape:        (15123, 51)
#
# Primary model-ready columns:
# ['TOTEXP23', 'TOTEXP23_log1p', 'AGE23X', 'SEX', 'RACETHX', 'HISPANX', 'MARRY23X', 'REGION23', 'EDUCYR', 'HIDEG', 'BORNUSA', 'FAMSZEYR', 'POVCAT23', 'FOODST23', 'RTHLTH42', 'MNHLTH42', 'HIBPDX', 'CHOLDX', 'DIABDX_M18', 'ASTHDX', 'ARTHDX', 'CANCERDX', 'CHDDX', 'STRKDX', 'EMPHDX', 'WLKLIM31', 'ACTLIM31', 'SOCLIM31', 'COGLIM31', 'DFHEAR42', 'DFSEE42', 'DFCOG42', 'DFWLKC42', 'DFDRSB42', 'DFERND42', 'ANYLMI23', 'INSCOPE', 'INSC1231', 'HAVEUS42', 'OFFER31X', 'HELD31X', 'DLAYCA42', 'AFRDCA42', 'DLAYPM42', 'AFRDPM42', 'DLAYDN42', 'AFRDDN42', 'chronic_condition_count', 'limitation_indicator_count', 'physical_difficulty_count', 'access_barrier_count']

# %% [markdown]
# ## Final missingness check before saving the primary file
#
# The primary model-ready file should have no missing target values. Predictor missingness should be limited and explainable. Any remaining missing values will be handled inside the modeling pipeline using imputation.

# %%
final_missing = (
    meps_model_ready_primary
    .isna()
    .sum()
    .reset_index()
    .rename(columns={"index": "variable", 0: "missing_count"})
)

final_missing["missing_rate"] = final_missing["missing_count"] / len(meps_model_ready_primary)
final_missing = final_missing.sort_values("missing_rate", ascending=False)

final_missing.head(25)
# Out:
#     variable  missing_count  missing_rate
# 13  FOODST23            522      0.034517
# 28  COGLIM31            334      0.022086
# 35  ANYLMI23            210      0.013886
# 27  SOCLIM31            203      0.013423
# 26  ACTLIM31            190      0.012564
# 25  WLKLIM31            182      0.012035
# 17    CHOLDX            154      0.010183
# 8     EDUCYR            149      0.009853
# 16    HIBPDX            144      0.009522
# 20    ARTHDX            141      0.009324
# 22     CHDDX            137      0.009059
# 21  CANCERDX            137      0.009059
# 23    STRKDX            134      0.008861
# 24    EMPHDX            134      0.008861
# 41  DLAYCA42            123      0.008133
# 42  AFRDCA42            116      0.007670
# 15  MNHLTH42            110      0.007274
# 44  AFRDPM42            107      0.007075
# 43  DLAYPM42            105      0.006943
# 46  AFRDDN42            104      0.006877
# 14  RTHLTH42            104      0.006877
# 45  DLAYDN42             99      0.006546
# 31   DFCOG42             71      0.004695
# 33  DFDRSB42             69      0.004563
# 34  DFERND42             67      0.004430

# %% [markdown]
# ## Save the primary MEPS model-ready file
#
# The saved file is the headline regression-ready version for Part II. It is restricted to adults (`AGE23X >= 18`) to match the NHIS Sample Adult scope, uses `POVCAT23` as the primary poverty feature, excludes `POVLEV23`, `WRKLIM31`, and the SAQ mental-health variables, and removes all dollar/utilization columns that would leak `TOTEXP23`. The companion sensitivity file (`meps_model_ready_v1_with_saq.csv`) adds the SAQ mental-health variables back in for analyses that want to condition on the SAQ subframe.
#
# We will stop adding variables here and move into modeling next. Other ideas (event-level merges, derived utilization indicators not tied to the dollar file) are noted as extensions for a follow-up version.

# %%
primary_path = DATA_PROCESSED / "meps_model_ready_v1.csv"

meps_model_ready_primary.to_csv(primary_path, index=False)

print("Saved:", primary_path)
print("Saved shape:", meps_model_ready_primary.shape)
# Out:
# Saved: /content/drive/MyDrive/med_project/data/processed/meps_model_ready_v1.csv
# Saved shape: (15123, 51)
